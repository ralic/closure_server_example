// %%
//http://nbviewer.jupyter.org/gist/jaredly/404a36306fdee6a1737a
var d3= require('d3')
var os = require('os');http://localhost:9999/notebooks/GNUc2c.ipynb#
os.hostname()
// Out:
// "PC-J3PFAG000348"

// %%
// var babel = require('babel');
%load_ext babel

// %%
%%babel
class Something {
    constructor() {
        console.log('Welcome!')
    }
    doit() {
        return false
    }
}

new Something().doit()
// Out:
// Welcome!
// false

// %%
display("<h1>Hello World</h1>", "text/html")
// Out:
// <h1>Hello World</h1>

// %%
var jsdom = require("jsdom");
var { JSDOM } = jsdom;

var dom = new JSDOM(`<!DOCTYPE html><p>Hello world</p>`);
console.log(dom.window.document.querySelector("p").textContent);
// Out:
// Hello world

// %%
var request = require('request');

var headers = {
    'authority': 'www.google.com',
    'cache-control': 'max-age=0',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/66.0.3359.117 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'zh-TW,zh;q=0.9,en-US;q=0.8,en;q=0.7',
    'cookie': 'NID=128=hcVW7jukCrJv-22TWLTLy6UKPQgscW5Xj427MUPipve46GV6Poij89B9zBVXhMRVs98hYVBBHW2RfYnO-KD0dJwuXGyhTlCTL_mKh45vCzJhGJXQeh5iaIxievaJ6rgE; 1P_JAR=2018-4-25-17'
};

var options = {
    url: 'https://www.google.com/?gws_rd=ssl',
    headers: headers
};

var resp;
var flag=true;
var callback= function (error, response, body) {
    if (!error && response.statusCode == 200) {
       resp=response;
       flag=false;
    }
}

// %%
console.log(flag)
// Out:
// true

// %%
var sleep = require('system-sleep');
var start = new Date();
var end ;
var samplerate=5;
if (flag) {
    end= new Date();    
    request(options,callback);
    console.log(resp)
    sleep(samplerate);
}
var elapsed= start.getTime()-end.getTime()
console.log("Time elapsed :"+elapsed+"msec")
// Out:
// Time elapsed :106193msec

// %%
// resp.body

// %%
display(resp.body, "text/html")
// Out:
// QےCңIے��#����#}\m+��Z��q4bx�gzq�8��@�6R����?�e��2*!.k(9��G�~�vM�}�I�\�^�8!�}���S�WA'�����{15�
// ��!gJT6۶J��xe��i�xiYF��*��Jx��Z9r�c��h�;���wl'�=>��0��hh_��T1�
// i�ϟ�ǎE�8nz�(�a~
// �n���7��~<���pE_�!��0V@�iM���ҽ�	,e
// ��_�V�Υ.�`�'$#d��|�{ղ
// s4�/,�j�TnvK(�
// K�WηnD��(6�i�)p�:A�xtx���"	T(�H������H�ԣFd&>��8vw�N=�k,J����������+w�=�I�}/��J�������ڨ�ѰzrA�X��Ӷ�벘j+2�k�b\ə	�H�|!��2m-��� �ak�.���/b\Ar}�
// Ǔ����$�\��a�s�&��y����;_G�c�ۯ�}4A�mj�G�r]�+g\����X)_��V$��~�3.'�År\����0�p��|��<x�-J��2��X���f��mMY)�8��a3ݪDq_�&��
// 1�\����+�����(���m�h��m��.b�����1�*�Yg��&�;؄9�^`ǥ�f���mu�ͬ��	UI�q��������j��t��lh4�\��jwH���ڲ
// iDN���'UH
// L'���J���6��MP)����ȀR���c3��vJ�є�Y)Jކ��ermx�/
// I�tƜp� �j����T2�����dO�R�Q��k�q?g|�
// ������
// օ�`!�;�>w|���۟g���d`�k�~Tվ2�o�f\�ؖ�VP?#�Đ�pgЊI�I�+0��].1ģ"�ԴEd�;��QY
// ;n _䢼k�}Q-��K�	8�
// ���M�OiM�O�`�@�� Uk�|ʩ�����p�[����-���\F�E�!.��r��3��z���Da�N���&�'�t�\��G�ߢf�;������$�yӕ�^��I�5F�~��Z��$����a��e&�.]`ZkW6X�_�D��o,x�7o?�v��S��ޭ���WF*��Q�|
// ...

// %%
var rp = require('request-promise');

var cheerio = require('cheerio'); // Basically jQuery for node.js 
 
var options2 = {
    uri: 'https://insynerger.com/',
    transform: function (body) {
        return cheerio.load(body);
    }
};
 
rp(options2)
    .then(function ($) {
        // Process html like you would with jQuery... 
//        console.log($('body'))
        var jqHTML=$('html').html()
//         console.log(jqHTML)
        var jqHTMLframed="<div style='height:768px'>"+jqHTML+"</div>"
        display(jqHTMLframed, "text/html") 
    }).catch(function (err) {
        console.log("Error")
        // Crawling failed or Cheerio choked... 
    });
// Out:
// evalmachine.<anonymous>:18
//         var jqHTMLframed="<div style="height:768px"">"+jqHTML+"</div>"
//                                       ^^^^^^
//
// SyntaxError: Unexpected identifier
//     at new Script (vm.js:51:7)
//     at createScript (vm.js:136:10)
//     at Object.runInContext (vm.js:181:10)
//     at Context.rawRun (C:\Users\raliclo\.ipython\kernels\nodejs\jupyter-nodejs\build\context.js:184:30)
//     at Domain.<anonymous> (C:\Users\raliclo\.ipython\kernels\nodejs\jupyter-nodejs\build\context.js:204:27)
//     at Domain.run (domain.js:323:14)
//     at Context.rawEvaluate (C:\Users\raliclo\.ipython\kernels\nodejs\jupyter-nodejs\build\context.js:202:9)
//     at Context.execute (C:\Users\raliclo\.ipython\kernels\nodejs\jupyter-nodejs\build\context.js:354:21)
//     at Kernel.executeRequest (C:\Users\raliclo\.ipython\kernels\nodejs\jupyter-nodejs\build\kernel.js:224:16)
// ...
